# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# fields of study, Germany 2024
df = pd.read_csv('./datasets/21311-0006_de_flat.csv',sep=';')

# %%
df.head().T
# Out:
#                                                   0                        1  \
# statistics_code                               21311                    21311
# statistics_label            Statistik der Studenten  Statistik der Studenten
# time_code                                    SEMEST                   SEMEST
# time_label                                 Semester                 Semester
# time                                     2023-10P6M               2023-10P6M
# 1_variable_code                               DLAND                    DLAND
# 1_variable_label                       Bundesländer             Bundesländer
# 1_variable_attribute_code                         7                        2
# 1_variable_attribute_label          Rheinland-Pfalz                  Hamburg
# 2_variable_code                                 NAT                      NAT
# 2_variable_label                       Nationalität             Nationalität
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42192 entries, 0 to 42191
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   statistics_code             42192 non-null  int64
#  1   statistics_label            42192 non-null  object
#  2   time_code                   42192 non-null  object
#  3   time_label                  42192 non-null  object
#  4   time                        42192 non-null  object
#  5   1_variable_code             42192 non-null  object
#  6   1_variable_label            42192 non-null  object
#  7   1_variable_attribute_code   42192 non-null  int64
#  8   1_variable_attribute_label  42192 non-null  object
#  9   2_variable_code             42192 non-null  object
#  10  2_variable_label            42192 non-null  object
#  11  2_variable_attribute_code   28128 non-null  object
#  12  2_variable_attribute_label  42192 non-null  object
# ...

# %%
df.time.unique()
# Out:
# array(['2023-10P6M'], dtype=object)

# %%
df.columns
# Out:
# Index(['statistics_code', 'statistics_label', 'time_code', 'time_label',
#        'time', '1_variable_code', '1_variable_label',
#        '1_variable_attribute_code', '1_variable_attribute_label',
#        '2_variable_code', '2_variable_label', '2_variable_attribute_code',
#        '2_variable_attribute_label', '3_variable_code', '3_variable_label',
#        '3_variable_attribute_code', '3_variable_attribute_label',
#        '4_variable_code', '4_variable_label', '4_variable_attribute_code',
#        '4_variable_attribute_label', 'value', 'value_unit',
#        'value_variable_code', 'value_variable_label', 'value_q'],
#       dtype='object')
